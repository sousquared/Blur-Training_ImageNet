# %%
import torch

# %%
check_path = '../logs/models/test02/checkpoint_000.pth.tar'
checkpoint = torch.load(check_path)

# %%
checkpoint['epoch']
# Out:
# 1

# %%
checkpoint['arch']
# Out:
# 'alexnet'

# %%
checkpoint['state_dict']
# Out:
# OrderedDict([('features.module.0.weight',
#               tensor([[[[ 0.0347,  0.0393, -0.0119,  ...,  0.0440, -0.0372,  0.0440],
#                         [ 0.0062,  0.0340,  0.0060,  ...,  0.0134, -0.0225, -0.0062],
#                         [-0.0237,  0.0305, -0.0427,  ...,  0.0480, -0.0422,  0.0387],
#                         ...,
#                         [-0.0267,  0.0148,  0.0140,  ...,  0.0565, -0.0069, -0.0082],
#                         [-0.0477, -0.0267,  0.0186,  ..., -0.0139, -0.0302, -0.0201],
#                         [ 0.0491,  0.0093,  0.0191,  ..., -0.0074, -0.0168,  0.0120]],
#
#                        [[-0.0219, -0.0070, -0.0366,  ..., -0.0011,  0.0556,  0.0273],
#                         [-0.0447,  0.0326, -0.0155,  ...,  0.0295, -0.0303,  0.0493],
#                         [-0.0368, -0.0085,  0.0118,  ..., -0.0137,  0.0040, -0.0295],
#                         ...,
#                         [ 0.0269,  0.0415,  0.0335,  ..., -0.0094,  0.0249, -0.0155],
# ...

# %%
checkpoint['optimizer']['param_groups']
# Out:
# [{'lr': 0.01,
#   'momentum': 0.9,
#   'dampening': 0,
#   'weight_decay': 0.0001,
#   'nesterov': False,
#   'params': [139988462368088,
#    139988462370680,
#    139988462370752,
#    139988462420040,
#    139988462420112,
#    139988462420184,
#    139988462420256,
#    139988462420328,
#    139988462420400,
#    139988462420472,
#    139988462420544,
#    139988462420616,
#    139988462420688,
#    139988462420760,
#    139988462420832,
#    139988462420904]}]

# %%
checkpoint['optimizer']['param_groups'][0]['lr']
# Out:
# 0.010000000000000002

# %%
best_path = '../logs/params/test06/model_best.pth.tar'
best = torch.load(best_path)

# %%
best['epoch']
# Out:
# 2

# %%
best['best_acc1']
# Out:
# tensor(9.3780, device='cuda:0')

# %%
best['optimizer']
# Out:
# {'state': {140106933609816: {'momentum_buffer': tensor([[[[ 1.4313e-03,  1.6701e-03,  1.4655e-03,  ...,  3.7626e-03,
#                4.7597e-03,  4.1160e-03],
#              [ 2.1108e-03,  1.9924e-03,  2.0865e-03,  ...,  3.2062e-03,
#                3.6742e-03,  3.8060e-03],
#              [ 3.5298e-03,  3.2155e-03,  2.9202e-03,  ...,  4.1486e-03,
#                4.4972e-03,  5.3779e-03],
#              ...,
#              [ 3.1528e-03,  2.7033e-03,  2.7562e-03,  ...,  3.1932e-03,
#                4.0638e-03,  4.3303e-03],
#              [ 3.6172e-03,  2.7760e-03,  3.2123e-03,  ...,  2.4417e-03,
#                3.8254e-03,  4.6102e-03],
#              [ 2.9952e-03,  2.2034e-03,  2.6072e-03,  ...,  2.5184e-03,
#                3.3607e-03,  4.2041e-03]],
#
#             [[ 4.1615e-03,  4.9155e-03,  5.2646e-03,  ...,  6.9240e-03,
#                7.7597e-03,  7.4816e-03],
#              [ 5.1698e-03,  5.3169e-03,  6.0226e-03,  ...,  6.4487e-03,
# ...

# %%
resume = 'hoge'
if resume:
    print('resume')
    print(resume)
else:
    print('init')
# Out:
# resume
# hoge
